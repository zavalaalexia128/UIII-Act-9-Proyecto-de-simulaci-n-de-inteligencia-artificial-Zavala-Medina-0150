# %% [markdown]
# <a href="https://colab.research.google.com/github/zavalaalexia128/UIII-Act-9-Proyecto-de-simulaci-n-de-inteligencia-artificial-Zavala-Medina-0150/blob/main/UIII_Act_9_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_Zavala_Medina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Alexia Zavala Medina NL= 59
# #### Relojero
# --- MENU RELOJERO ---
# 1. Registrar reloj
# 2. Ver inventario
# 3. Diagnostico Experto
# 4. Salir

# %%
Lista = []
opcion = ""

while opcion != "4":
    print("\n--- MENU ---")
    print("1. Registrar reloj")
    print("2. Ver inventario")
    print("3. Diagnostico Experto")
    print("4. Salir")

    opcion = input("Opcion: ")

    if opcion == "1":
        inventario.append(input("Marca: "))
        print("Guardado.")

    elif opcion == "2":
        if inventario == []:
            print("Vacio.")
        else:
            print(inventario)

    elif opcion == "3":
        tipo = input("Tipo (mecanico/cuarzo): ")
        if tipo == "mecanico":
            print("Solucion IA: Ajustar volante o dar cuerda.")
        if tipo == "cuarzo":
            print("Solucion IA: Cambiar la bateria.")

    elif opcion == "4":
     print("Saliendo del programa")
     print("Programa realizado por Zavala Meedina Alexia NL = 59")
# Out:
# --- MENU ---
# 1. Registrar reloj
# 2. Ver inventario
# 3. Diagnostico Experto
# 4. Salir
# Opcion: 1
# Marca: casio
# Guardado.
#
# --- MENU ---
# 1. Registrar reloj
# 2. Ver inventario
# 3. Diagnostico Experto
# 4. Salir
# Opcion: 2
# ['casio']
#
# --- MENU ---
# 1. Registrar reloj
# 2. Ver inventario
# 3. Diagnostico Experto
# 4. Salir
# Opcion: 1
# Marca: rolex
# Guardado.
#
# --- MENU ---
# 1. Registrar reloj
# 2. Ver inventario
# 3. Diagnostico Experto
# 4. Salir
# Opcion: 1
# Marca: omega
# Guardado.
#
# --- MENU ---
# 1. Registrar reloj
# 2. Ver inventario
# 3. Diagnostico Experto
# 4. Salir
# Opcion: 2
# ['casio', 'rolex', 'omega']
#
# --- MENU ---
# 1. Registrar reloj
# 2. Ver inventario
# 3. Diagnostico Experto
# 4. Salir
# Opcion: 3
# Tipo (mecanico/cuarzo): mecanico
# Solucion IA: Ajustar volante o dar cuerda.
#
# --- MENU ---
# 1. Registrar reloj
# 2. Ver inventario
# 3. Diagnostico Experto
# 4. Salir
# Opcion: 4
# Saliendo del programa
# ...

# %% [markdown]
# ![](https://raw.githubusercontent.com/zavalaalexia128/UIII-Act-9-Proyecto-de-simulaci-n-de-inteligencia-artificial-Zavala-Medina-0150/refs/heads/main/infografiarelojero.png)
